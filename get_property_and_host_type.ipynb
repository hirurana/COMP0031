# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./en_reviews/buenosaires_en.csv')
listings = pd.read_csv('./listings/buenosaires_listings.csv')
listings
# Out:
#              id                                       name    host_id  \
# 0          7270        ¡¡Great Loft in Palermo Hollywood!!      18822
# 1         11508         Amazing Luxurious Apt-Palermo Soho      42762
# 2         12463        Room in Recoleta - awesome location      48799
# 3         13095         Standard Room at Palermo Viejo B&B      50994
# 4         13096         Standard Room in Palermo Viejo B&B      50994
# ...         ...                                        ...        ...
# 22872  40350240                         Mi hogar, tu hogar  285518660
# 22873  40351237                 Cozy room  in La Ponderosa  311888381
# 22874  40351485            Sunny room in Palermo Hollywood   64137265
# 22875  40351815           Studio Luminoso en Palermo Soho.  311868435
# 22876  40352426  Hermoso dpto en Caballito,luminoso,seguro  169760366
#
#          host_name  neighbourhood_group      neighbourhood  latitude  \
# 0             Toni                  NaN            Palermo -34.58241
# 1          Candela                  NaN            Palermo -34.58225
# 2             Matt                  NaN           Recoleta -34.59761
# 3            Ariel                  NaN            Palermo -34.59382
# 4            Ariel                  NaN            Palermo -34.59398
# ...            ...                  ...                ...       ...
# 22872      Rodrigo                  NaN   Parque Patricios -34.63427
# 22873        Laura                  NaN      Villa Urquiza -34.56871
# 22874        Akemi                  NaN            Palermo -34.58464
# 22875  Maria Laura                  NaN            Palermo -34.59070
# 22876        Belén                  NaN  Villa Gral. Mitre -34.61385
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -58.43382  Entire home/apt   2033              20                 14
# 1      -58.42460  Entire home/apt   3588               2                 25
# 2      -58.39468     Private room   1435               1                 20
# 3      -58.42994     Private room   2691               1                  1
# 4      -58.42853     Private room   2691               1                  0
# ...          ...              ...    ...             ...                ...
# 22872  -58.40749  Entire home/apt   1495               1                  0
# 22873  -58.50318     Private room   1196               1                  0
# 22874  -58.43219     Private room   2691               1                  0
# 22875  -58.42208  Entire home/apt   1375               3                  0
# 22876  -58.46594  Entire home/apt   1196               2                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-04-30               0.15                               1
# 1      2019-08-13               0.28                               1
# 2      2017-12-11               0.17                               1
# 3      2018-12-18               0.09                               7
# 4             NaN                NaN                               7
# ...           ...                ...                             ...
# 22872         NaN                NaN                               1
# 22873         NaN                NaN                               1
# 22874         NaN                NaN                               2
# 22875         NaN                NaN                               1
# 22876         NaN                NaN                               1
#
#        availability_365
# 0                   363
# 1                   281
# 2                   365
# 3                   360
# 4                   360
# ...                 ...
# 22872               178
# 22873               143
# 22874                 5
# 22875               152
# 22876               333
#
# [22877 rows x 16 columns]

# %%
df
# Out:
#         Unnamed: 0  listing_id         id        date  reviewer_id  \
# 0                0        7270    1015127  2012-03-18      1586988
# 1                1        7270    1041539  2012-03-25      1476835
# 2                2        7270    1122580  2012-04-13      2087599
# 3                3        7270    2580924  2012-10-11      1523475
# 4                4        7270    2795303  2012-11-03      3004044
# ...            ...         ...        ...         ...          ...
# 111367      354155    40013205  566083416  2019-11-18     97535792
# 111368      354173    40061613  566475410  2019-11-19      6304935
# 111369      354179    40080976  568459843  2019-11-24    299364524
# 111370      354188    40131070  568492128  2019-11-24     34965075
# 111371      354195    40152175  566040756  2019-11-18    265662103
#
#         reviewer_name                                           comments langs
# 0              Morgan  Great apartment in a fantastic location. Booke...    en
# 1             Terence  Toni was a great host and looked after me in B...    en
# 2       Antonio David  Toni is a great guy and has a great loft, bett...    en
# 3              Noémie  The apartment is very well located in the beau...    en
# 4               Jenna  We had a pleasant stay at the apartment! Toni ...    en
# ...               ...                                                ...   ...
# 111367          Johan  Everything was good with Noelia's appartment ,...    en
# 111368          Ariel  Great little place at the best location in tow...    en
# 111369           Dvir  The apartment is located in a really good and ...    en
# 111370        Viviana  Thomas was great and flexible also did respond...    en
# 111371          Simon  Alejandro is a very kindly host with a beautif...    en
#
# [111372 rows x 8 columns]

# %%
listings = listings[['id', 'room_type', 'calculated_host_listings_count']].copy()
listings
# Out:
#              id        room_type  calculated_host_listings_count
# 0          7270  Entire home/apt                               1
# 1         11508  Entire home/apt                               1
# 2         12463     Private room                               1
# 3         13095     Private room                               7
# 4         13096     Private room                               7
# ...         ...              ...                             ...
# 22872  40350240  Entire home/apt                               1
# 22873  40351237     Private room                               1
# 22874  40351485     Private room                               2
# 22875  40351815  Entire home/apt                               1
# 22876  40352426  Entire home/apt                               1
#
# [22877 rows x 3 columns]

# %%
listings['is_superhost'] = np.where(listings['calculated_host_listings_count'] >= 10, 'Yes', listings['calculated_host_listings_count'])
listings['is_superhost'] = np.where(listings['calculated_host_listings_count'] < 10, 'No', listings['is_superhost'])
listings = listings.rename(columns={"id": "listing_id"})
listings
# Out:
#        listing_id        room_type  calculated_host_listings_count  \
# 0            7270  Entire home/apt                               1
# 1           11508  Entire home/apt                               1
# 2           12463     Private room                               1
# 3           13095     Private room                               7
# 4           13096     Private room                               7
# ...           ...              ...                             ...
# 22872    40350240  Entire home/apt                               1
# 22873    40351237     Private room                               1
# 22874    40351485     Private room                               2
# 22875    40351815  Entire home/apt                               1
# 22876    40352426  Entire home/apt                               1
#
#       is_superhost
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ...            ...
# 22872           No
# 22873           No
# 22874           No
# 22875           No
# 22876           No
#
# [22877 rows x 4 columns]

# %%
out = pd.merge(df, listings, on='listing_id')
out
# Out:
#         Unnamed: 0  listing_id         id        date  reviewer_id  \
# 0                0        7270    1015127  2012-03-18      1586988
# 1                1        7270    1041539  2012-03-25      1476835
# 2                2        7270    1122580  2012-04-13      2087599
# 3                3        7270    2580924  2012-10-11      1523475
# 4                4        7270    2795303  2012-11-03      3004044
# ...            ...         ...        ...         ...          ...
# 111367      354155    40013205  566083416  2019-11-18     97535792
# 111368      354173    40061613  566475410  2019-11-19      6304935
# 111369      354179    40080976  568459843  2019-11-24    299364524
# 111370      354188    40131070  568492128  2019-11-24     34965075
# 111371      354195    40152175  566040756  2019-11-18    265662103
#
#         reviewer_name                                           comments  \
# 0              Morgan  Great apartment in a fantastic location. Booke...
# 1             Terence  Toni was a great host and looked after me in B...
# 2       Antonio David  Toni is a great guy and has a great loft, bett...
# 3              Noémie  The apartment is very well located in the beau...
# 4               Jenna  We had a pleasant stay at the apartment! Toni ...
# ...               ...                                                ...
# 111367          Johan  Everything was good with Noelia's appartment ,...
# 111368          Ariel  Great little place at the best location in tow...
# 111369           Dvir  The apartment is located in a really good and ...
# 111370        Viviana  Thomas was great and flexible also did respond...
# 111371          Simon  Alejandro is a very kindly host with a beautif...
#
#        langs        room_type  calculated_host_listings_count is_superhost
# 0         en  Entire home/apt                               1           No
# 1         en  Entire home/apt                               1           No
# 2         en  Entire home/apt                               1           No
# 3         en  Entire home/apt                               1           No
# 4         en  Entire home/apt                               1           No
# ...      ...              ...                             ...          ...
# 111367    en  Entire home/apt                               3           No
# 111368    en  Entire home/apt                               5           No
# 111369    en  Entire home/apt                               2           No
# 111370    en  Entire home/apt                               1           No
# 111371    en     Private room                               5           No
#
# [111372 rows x 11 columns]

# %%
out.to_csv(r'property_type_and_superhosts/buenosaires_type.csv')
