# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./en_reviews/tokyo_en.csv')
listings = pd.read_csv('./listings/tokyo_listings.csv')
listings
# Out:
#             id                            listing_url       scrape_id  \
# 0        49091     https://www.airbnb.com/rooms/49091  20191126102104
# 1        50646     https://www.airbnb.com/rooms/50646  20191126102104
# 2        56334     https://www.airbnb.com/rooms/56334  20191126102104
# 3        71609     https://www.airbnb.com/rooms/71609  20191126102104
# 4        71896     https://www.airbnb.com/rooms/71896  20191126102104
# ...        ...                                    ...             ...
# 7852  40369697  https://www.airbnb.com/rooms/40369697  20191126102104
# 7853  40374651  https://www.airbnb.com/rooms/40374651  20191126102104
# 7854  40375034  https://www.airbnb.com/rooms/40375034  20191126102104
# 7855  40382063  https://www.airbnb.com/rooms/40382063  20191126102104
# 7856  40382084  https://www.airbnb.com/rooms/40382084  20191126102104
#
#      last_scraped                                               name  \
# 0      2019-11-26                  COZICOMFORT LONG TERM STAY ROOM 2
# 1      2019-11-26                    Pleasant Room along Bukit Timah
# 2      2019-11-26                                        COZICOMFORT
# 3      2019-11-26                Ensuite Room (Room 1 & 2) near EXPO
# 4      2019-11-26                    B&B  Room 1 near Airport & EXPO
# ...           ...                                                ...
# 7852   2019-11-26              Cozy room in the central of Singapore
# 7853   2019-11-26  Common room@Holland Vill/Buona Vista/INSEAD/ESSEC
# 7854   2019-11-26   SINGLE RM@HOLLAND VILL/BUONA VISTA/INSEAD/ESSEC.
# 7855   2019-11-26    One bedroom apartment with excellent facilities
# 7856   2019-11-26         CLOSE TO HOUGANG 1 MALL, COMFORT 2BR SPACE
#
#                                                 summary  \
# 0                                                   NaN
# 1     Fully furnished bedroom with a nice view on th...
# 2                                                   NaN
# 3     For 3 (Website hidden by Airbnb) room 1&2 and ...
# 4                                                   NaN
# ...                                                 ...
# 7852  The place very near to central, very convenien...
# 7853  DOUBLE ROOM FOR ONE PERSON PRICED FOR  MINIMUM...
# 7854  SINGLE ROOM@HOLLAND VILLAGE/BUONA VISTA/INSEAD...
# 7855                                                NaN
# 7856  With a mall close-by, these spacious 2-bedroom...
#
#                                                   space  \
# 0     This is Room No. 2.(available after Jan 15 201...
# 1     Good Condition room, bright & windy. Comes wit...
# 2     This is Room no. 1. USD700 per month On the fa...
# 3     Landed Homestay Room for Rental. Between Simei...
# 4     Vocational Stay Deluxe Bedroom in Singapore.(N...
# ...                                                 ...
# 7852                                                NaN
# 7853                       Private room with double bed
# 7854                                                NaN
# 7855                                                NaN
# 7856  Spread into 850 sq.ft., these designer and com...
#
#                                             description experiences_offered  \
# 0     This is Room No. 2.(available after Jan 15 201...                none
# 1     Fully furnished bedroom with a nice view on th...                none
# 2     This is Room no. 1. USD700 per month On the fa...                none
# 3     For 3 (Website hidden by Airbnb) room 1&2 and ...                none
# 4     Vocational Stay Deluxe Bedroom in Singapore.(N...                none
# ...                                                 ...                 ...
# 7852  The place very near to central, very convenien...                none
# 7853  DOUBLE ROOM FOR ONE PERSON PRICED FOR  MINIMUM...                none
# 7854  SINGLE ROOM@HOLLAND VILLAGE/BUONA VISTA/INSEAD...                none
# 7855                                                NaN                none
# 7856  With a mall close-by, these spacious 2-bedroom...                none
#
#                                   neighborhood_overview  ... instant_bookable  \
# 0                                                   NaN  ...                f
# 1     The serenity & quiet surrounding makes it an i...  ...                f
# 2                                                   NaN  ...                f
# 3                                                   NaN  ...                t
# 4                                                   NaN  ...                t
# ...                                                 ...  ...              ...
# 7852                                                NaN  ...                t
# 7853                                                NaN  ...                t
# 7854                                                NaN  ...                t
# 7855                                                NaN  ...                f
# 7856  Located about half an hour drive from Changi A...  ...                f
#
#      is_business_travel_ready          cancellation_policy  \
# 0                           f                     flexible
# 1                           f                     moderate
# 2                           f                     flexible
# 3                           f                     moderate
# 4                           f                     moderate
# ...                       ...                          ...
# 7852                        f  strict_14_with_grace_period
# 7853                        f                     moderate
# 7854                        f                     moderate
# 7855                        f                     flexible
# 7856                        f  strict_14_with_grace_period
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                t                                t
# 1                                f                                t
# 2                                t                                t
# 3                                f                                t
# 4                                f                                t
# ...                            ...                              ...
# 7852                             f                                f
# 7853                             f                                f
# 7854                             f                                f
# 7855                             f                                f
# 7856                             f                                f
#
#       calculated_host_listings_count  \
# 0                                  2
# 1                                  1
# 2                                  2
# 3                                  8
# 4                                  8
# ...                              ...
# 7852                               1
# 7853                              16
# 7854                              16
# 7855                               1
# 7856                              82
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 7852                                            0
# 7853                                            3
# 7854                                            3
# 7855                                            1
# 7856                                           77
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               2
# 1                                               1
# 2                                               2
# 3                                               8
# 4                                               8
# ...                                           ...
# 7852                                            1
# 7853                                           13
# 7854                                           13
# 7855                                            0
# 7856                                            5
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.01
# 1                                               0               0.26
# 2                                               0               0.19
# 3                                               0               0.16
# 4                                               0               0.24
# ...                                           ...                ...
# 7852                                            0                NaN
# 7853                                            0                NaN
# 7854                                            0                NaN
# 7855                                            0                NaN
# 7856                                            0                NaN
#
# [7857 rows x 106 columns]

# %%
df
# Out:
#        Unnamed: 0  listing_id         id        date  reviewer_id  \
# 0               0       49091    8243238  2013-10-21      8557223
# 1               1       50646   11909864  2014-04-18      1356099
# 2               2       50646   13823948  2014-06-05     15222393
# 3               3       50646   15117222  2014-07-02      5543172
# 4               4       50646   15426462  2014-07-08       817532
# ...           ...         ...        ...         ...          ...
# 87071      107313    40012885  567620467  2019-11-23    217423388
# 87072      107314    40014434  567626111  2019-11-23    290039148
# 87073      107316    40129228  568117993  2019-11-24    290391105
# 87074      107317    40138508  566024301  2019-11-18    217531255
# 87075      107319    40226189  566900233  2019-11-21    164625805
#
#       reviewer_name                                           comments langs
# 0             Jared  Fran was absolutely gracious and welcoming. Ma...    en
# 1             James  A comfortable room in a smart condo developmen...    en
# 2             Welli  Stayed over at Sujatha's house for 3 good nigh...    en
# 3             Cyril  It's been a lovely stay at Sujatha's. The room...    en
# 4              Jake  We had a great experience. A nice place, an am...    en
# ...             ...                                                ...   ...
# 87071           Mia  amazing customer service from michelle! the pl...    en
# 87072      Shunsuke  It's small but great value for money. \nKaurus...    en
# 87073         Savas  Room was very clean , location is 10 minutes w...    en
# 87074        Nicole  Bathroom floor tiles were extremely slimy and ...    en
# 87075             J  A understanding and responsive host who is abl...    en
#
# [87076 rows x 8 columns]

# %%
listings = listings[['id', 'room_type', 'calculated_host_listings_count']].copy()
listings
# Out:
#             id        room_type  calculated_host_listings_count
# 0        49091     Private room                               2
# 1        50646     Private room                               1
# 2        56334     Private room                               2
# 3        71609     Private room                               8
# 4        71896     Private room                               8
# ...        ...              ...                             ...
# 7852  40369697     Private room                               1
# 7853  40374651     Private room                              16
# 7854  40375034     Private room                              16
# 7855  40382063  Entire home/apt                               1
# 7856  40382084  Entire home/apt                              82
#
# [7857 rows x 3 columns]

# %%
listings['is_superhost'] = np.where(listings['calculated_host_listings_count'] >= 10, 'Yes', listings['calculated_host_listings_count'])
listings['is_superhost'] = np.where(listings['calculated_host_listings_count'] < 10, 'No', listings['is_superhost'])
listings = listings.rename(columns={"id": "listing_id"})
listings
# Out:
#       listing_id        room_type  calculated_host_listings_count is_superhost
# 0          49091     Private room                               2           No
# 1          50646     Private room                               1           No
# 2          56334     Private room                               2           No
# 3          71609     Private room                               8           No
# 4          71896     Private room                               8           No
# ...          ...              ...                             ...          ...
# 7852    40369697     Private room                               1           No
# 7853    40374651     Private room                              16          Yes
# 7854    40375034     Private room                              16          Yes
# 7855    40382063  Entire home/apt                               1           No
# 7856    40382084  Entire home/apt                              82          Yes
#
# [7857 rows x 4 columns]

# %%
out = pd.merge(df, listings, on='listing_id')
out
# Out:
#        Unnamed: 0  listing_id         id        date  reviewer_id  \
# 0               0       49091    8243238  2013-10-21      8557223
# 1               1       50646   11909864  2014-04-18      1356099
# 2               2       50646   13823948  2014-06-05     15222393
# 3               3       50646   15117222  2014-07-02      5543172
# 4               4       50646   15426462  2014-07-08       817532
# ...           ...         ...        ...         ...          ...
# 87071      107313    40012885  567620467  2019-11-23    217423388
# 87072      107314    40014434  567626111  2019-11-23    290039148
# 87073      107316    40129228  568117993  2019-11-24    290391105
# 87074      107317    40138508  566024301  2019-11-18    217531255
# 87075      107319    40226189  566900233  2019-11-21    164625805
#
#       reviewer_name                                           comments langs  \
# 0             Jared  Fran was absolutely gracious and welcoming. Ma...    en
# 1             James  A comfortable room in a smart condo developmen...    en
# 2             Welli  Stayed over at Sujatha's house for 3 good nigh...    en
# 3             Cyril  It's been a lovely stay at Sujatha's. The room...    en
# 4              Jake  We had a great experience. A nice place, an am...    en
# ...             ...                                                ...   ...
# 87071           Mia  amazing customer service from michelle! the pl...    en
# 87072      Shunsuke  It's small but great value for money. \nKaurus...    en
# 87073         Savas  Room was very clean , location is 10 minutes w...    en
# 87074        Nicole  Bathroom floor tiles were extremely slimy and ...    en
# 87075             J  A understanding and responsive host who is abl...    en
#
#           room_type  calculated_host_listings_count is_superhost
# 0      Private room                               2           No
# 1      Private room                               1           No
# 2      Private room                               1           No
# 3      Private room                               1           No
# 4      Private room                               1           No
# ...             ...                             ...          ...
# 87071  Private room                               6           No
# 87072  Private room                             120          Yes
# 87073  Private room                               2           No
# 87074  Private room                               1           No
# 87075  Private room                              64          Yes
#
# [87076 rows x 11 columns]

# %%
out.to_csv(r'property_type_and_superhosts/tokyo_type.csv')
