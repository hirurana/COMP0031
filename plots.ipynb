# %%
import pandas as pd
import collections
import numpy as np
import seaborn as sns

from langdetect import detect

# %%
# df = pd.read_csv('./brazil/brazil_reviews.csv')
# df = pd.read_csv('./samerica/santiago.csv')
df = pd.read_csv('./buenos_aires/buenos_aires_reviews.csv')

# %%
df
# Out:
#         listing_id         id        date  reviewer_id    reviewer_name  \
# 0             7270    1015127  2012-03-18      1586988           Morgan
# 1             7270    1041539  2012-03-25      1476835          Terence
# 2             7270    1122580  2012-04-13      2087599    Antonio David
# 3             7270    2580924  2012-10-11      1523475           Noémie
# 4             7270    2795303  2012-11-03      3004044            Jenna
# ...            ...        ...         ...          ...              ...
# 354199    40182934  567402061  2019-11-22     42254098          Agustin
# 354200    40182934  568444634  2019-11-24    310686380          Agustin
# 354201    40229262  566589862  2019-11-19    310754674  Enrique Eduardo
# 354202    40277986  567442064  2019-11-22    139274240           Karina
# 354203    40279750  567806548  2019-11-23    310909113              Eva
#
#                                                  comments
# 0       Great apartment in a fantastic location. Booke...
# 1       Toni was a great host and looked after me in B...
# 2       Toni is a great guy and has a great loft, bett...
# 3       The apartment is very well located in the beau...
# 4       We had a pleasant stay at the apartment! Toni ...
# ...                                                   ...
# 354199  El apartamento de Polo es ideal cuando se esta...
# 354200  Excelente ubicacion y atención. Lugar muy cómo...
# 354201  The host canceled this reservation 2 days befo...
# 354202  Thomas es un anfitrión sumamente amable. Queda...
# 354203  Pieza sencilla, muy buena predisposición, exce...
#
# [354204 rows x 6 columns]

# %%
df2 = df[df.comments.str[:34] != "The host canceled this reservation"]
df2 = df.head(1000)
df2
# Out:
#      listing_id       id        date  reviewer_id  reviewer_name  \
# 0          7270  1015127  2012-03-18      1586988         Morgan
# 1          7270  1041539  2012-03-25      1476835        Terence
# 2          7270  1122580  2012-04-13      2087599  Antonio David
# 3          7270  2580924  2012-10-11      1523475         Noémie
# 4          7270  2795303  2012-11-03      3004044          Jenna
# ..          ...      ...         ...          ...            ...
# 995       24157  5786902  2013-07-16      6645357     Christophe
# 996       24157  5889360  2013-07-21      5062316          David
# 997       24157  6287101  2013-08-06      6747811      Guillaume
# 998       24157  6586767  2013-08-18      6886501          Renee
# 999       24157  8764039  2013-11-17       955942        Rebekah
#
#                                               comments
# 0    Great apartment in a fantastic location. Booke...
# 1    Toni was a great host and looked after me in B...
# 2    Toni is a great guy and has a great loft, bett...
# 3    The apartment is very well located in the beau...
# 4    We had a pleasant stay at the apartment! Toni ...
# ..                                                 ...
# 995  Some details about our stay:\nReception: Angel...
# 996  Angela was away when I arrived; however, her v...
# 997  Very good stay at this location ! very well lo...
# 998  Muy encantadora Virginie, el loft es un muy bu...
# 999  This loft was amazing, and in a great neighbor...
#
# [1000 rows x 6 columns]

# %%
# mean review length ignoring languages
df3 = df2['comments']
dfl = df3.str.len()
dfl.mean(axis = 0)
# Out:
# 342.991

# %%
# creates table with languages distribution
langs = []
for i in df3:
    try:
        langs.append(detect(i))
    except:
        langs.append('Nan')
        continue
# Out:
# ['en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'de',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'es',
#  'es',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'pt',
#  'es',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'pt',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'pt',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'es',
#  'es',
#  'es',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'es',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'pt',
#  'pt',
#  'es',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'es',
#  'es',
#  'en',
#  'en',
#  'es',
#  'fr',
#  'en',
#  'en',
#  'pt',
#  'pt',
#  'fr',
#  'en',
#  'en',
#  'es',
#  'en',
#  'pt',
#  'fr',
#  'es',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'ro',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'de',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'de',
#  'en',
#  'es',
#  'en',
#  'pt',
#  'es',
#  'en',
#  'es',
#  'es',
#  'en',
#  'es',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'Nan',
#  'en',
#  'en',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'es',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'es',
#  'es',
#  'es',
#  'Nan',
#  'es',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'fr',
#  'pt',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'en',
#  'pt',
#  'it',
#  'pt',
#  'en',
#  'es',
#  'pt',
#  'fr',
#  'pt',
#  'es',
#  'pt',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'pt',
#  'es',
#  'en',
#  'pt',
#  'es',
#  'pt',
#  'pt',
#  'en',
#  'es',
#  'en',
#  'es',
#  'ro',
#  'es',
#  'en',
#  'en',
#  'es',
#  'es',
#  'es',
#  'es',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'es',
#  'es',
#  'en',
#  'fr',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'en',
#  'es',
#  'fr',
#  'fr',
#  'en',
#  'pt',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'es',
#  'de',
#  'en',
#  'Nan',
#  'fr',
#  'en',
#  'en',
#  'fr',
#  'es',
#  'es',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'de',
#  'es',
#  'pt',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'it',
#  'en',
#  'es',
#  'es',
#  'en',
#  'en',
#  'es',
#  'es',
#  'fr',
#  'es',
#  'fr',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'pt',
#  'en',
#  'es',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'de',
#  'en',
#  'es',
#  'en',
#  'en',
#  'pt',
#  'pt',
#  'en',
#  'en',
#  'it',
#  'es',
#  'en',
#  'en',
#  'pt',
#  'es',
#  'pt',
#  'pt',
#  'pt',
#  'pt',
#  'pt',
#  'it',
#  'pt',
#  'pt',
#  'en',
#  'en',
#  'pt',
#  'es',
#  'pt',
#  'en',
#  'pt',
#  'fr',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'pt',
#  'pt',
#  'es',
#  'pt',
#  'es',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'es',
#  'pt',
#  'es',
#  'en',
#  'pt',
#  'pt',
#  'en',
#  'de',
#  'es',
#  'pt',
#  'es',
#  'en',
#  'en',
#  'es',
#  'it',
#  'es',
#  'pt',
#  'fr',
#  'pt',
#  'es',
#  'fr',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'es',
#  'pt',
#  'pt',
#  'en',
#  'es',
#  'es',
#  'es',
#  'fr',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'es',
#  'fr',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'en',
#  'en',
#  'es',
#  'es',
#  'es',
#  'pt',
#  'pt',
#  'es',
#  'pt',
#  'pt',
#  'en',
#  'es',
#  'es',
#  'en',
#  'pt',
#  'en',
#  'pt',
#  'pt',
#  'pt',
#  'en',
#  'es',
#  'es',
#  'en',
#  'pt',
#  'pt',
#  'pt',
#  'es',
#  'es',
#  'pt',
#  'fr',
#  'es',
#  'pt',
#  'en',
#  'es',
#  'pt',
#  'es',
#  'en',
#  'pt',
#  'pt',
#  'es',
#  'en',
#  'en',
#  'de',
#  'es',
#  'en',
#  'es',
#  'pt',
#  'en',
#  'pt',
#  'pt',
#  'en',
#  'pt',
#  'pt',
#  'pt',
#  'es',
#  'pt',
#  'pt',
#  'pt',
#  'pt',
#  'es',
#  'pt',
#  'es',
#  'pt',
#  'es',
#  'pt',
#  'es',
#  'es',
#  'pt',
#  'pt',
#  'pt',
#  'pt',
#  'es',
#  'pt',
#  'pt',
#  'en',
#  'pt',
#  'pt',
#  'es',
#  'es',
#  'en',
#  'es',
#  'es',
#  'pt',
#  'es',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'pt',
#  'fr',
#  'fr',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'no',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'es',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'es',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'pt',
#  'ro',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'it',
#  'ca',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'cs',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'de',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'nl',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'es',
#  'en',
#  'es',
#  'pt',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'es',
#  'en',
#  'sw',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'en',
#  'pt',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'de',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'fr',
#  'en',
#  'de',
#  'en',
#  'de',
#  'fr',
#  'fr',
#  'en',
#  'en',
#  'es',
#  'en',
#  'ko',
#  'fr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'de',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en']

# %%
c = collections.Counter(langs)
freq = pd.DataFrame.from_dict(c, orient='index').reset_index()

# %%
freq = freq.apply(lambda x: x/len(df3) if x.name == 0 else x)

# %%
freq_sorted = freq.sort_values(by= [0], ascending=False)
freq_sorted
# Out:
#    index      0
# 0     en  0.620
# 1     es  0.183
# 3     pt  0.123
# 4     fr  0.042
# 2     de  0.014
# 7     it  0.006
# 5     ro  0.003
# 6    Nan  0.003
# 8     no  0.001
# 9     ca  0.001
# 10    cs  0.001
# 11    nl  0.001
# 12    sw  0.001
# 13    ko  0.001

# %%
export = freq_sorted.reset_index(drop=True)

# %%
export.to_csv(r'buenosaireslangs.csv')

# %%
# begin analysing specific languages
dfnew = df2.copy()
dfnew['lang'] = langs
dfnew
# Out:
#      listing_id       id        date  reviewer_id  reviewer_name  \
# 0          7270  1015127  2012-03-18      1586988         Morgan
# 1          7270  1041539  2012-03-25      1476835        Terence
# 2          7270  1122580  2012-04-13      2087599  Antonio David
# 3          7270  2580924  2012-10-11      1523475         Noémie
# 4          7270  2795303  2012-11-03      3004044          Jenna
# ..          ...      ...         ...          ...            ...
# 995       24157  5786902  2013-07-16      6645357     Christophe
# 996       24157  5889360  2013-07-21      5062316          David
# 997       24157  6287101  2013-08-06      6747811      Guillaume
# 998       24157  6586767  2013-08-18      6886501          Renee
# 999       24157  8764039  2013-11-17       955942        Rebekah
#
#                                               comments lang
# 0    Great apartment in a fantastic location. Booke...   en
# 1    Toni was a great host and looked after me in B...   en
# 2    Toni is a great guy and has a great loft, bett...   en
# 3    The apartment is very well located in the beau...   en
# 4    We had a pleasant stay at the apartment! Toni ...   en
# ..                                                 ...  ...
# 995  Some details about our stay:\nReception: Angel...   en
# 996  Angela was away when I arrived; however, her v...   en
# 997  Very good stay at this location ! very well lo...   en
# 998  Muy encantadora Virginie, el loft es un muy bu...   es
# 999  This loft was amazing, and in a great neighbor...   en
#
# [1000 rows x 7 columns]

# %%
# first english
df_en = dfnew.loc[dfnew['lang'] == 'en'].copy()

# %%
df_en['len'] = df_en['comments'].str.len()
df_en
# Out:
#      listing_id       id        date  reviewer_id  reviewer_name  \
# 0          7270  1015127  2012-03-18      1586988         Morgan
# 1          7270  1041539  2012-03-25      1476835        Terence
# 2          7270  1122580  2012-04-13      2087599  Antonio David
# 3          7270  2580924  2012-10-11      1523475         Noémie
# 4          7270  2795303  2012-11-03      3004044          Jenna
# ..          ...      ...         ...          ...            ...
# 994       24157  5640663  2013-07-09      3705041          Sally
# 995       24157  5786902  2013-07-16      6645357     Christophe
# 996       24157  5889360  2013-07-21      5062316          David
# 997       24157  6287101  2013-08-06      6747811      Guillaume
# 999       24157  8764039  2013-11-17       955942        Rebekah
#
#                                               comments lang   len
# 0    Great apartment in a fantastic location. Booke...   en   152
# 1    Toni was a great host and looked after me in B...   en   162
# 2    Toni is a great guy and has a great loft, bett...   en   247
# 3    The apartment is very well located in the beau...   en  1881
# 4    We had a pleasant stay at the apartment! Toni ...   en  1438
# ..                                                 ...  ...   ...
# 994  We loved our stay in the San Telmo Loft! Angel...   en   358
# 995  Some details about our stay:\nReception: Angel...   en  1329
# 996  Angela was away when I arrived; however, her v...   en   601
# 997  Very good stay at this location ! very well lo...   en   298
# 999  This loft was amazing, and in a great neighbor...   en   184
#
# [620 rows x 8 columns]

# %%
# show mean
en_mean = np.mean(df_en['len'])
en_mean
# Out:
# 385.08870967741933

# %%
# show max value
df_en['len'].max()
# Out:
# 2666

# %%
# then spanish
df_es = dfnew.loc[dfnew['lang'] == 'es'].copy()

# %%
df_es['len'] = df_es['comments'].str.len()
df_es
# Out:
#      listing_id         id        date  reviewer_id reviewer_name  \
# 11         7270  116663731  2016-12-02    102925474       Claudia
# 13         7270  259174711  2018-04-30     57734717         Clara
# 25        11508   68315541  2016-04-04     12506315        Javier
# 28        11508  124172812  2017-01-01     24103270        Andres
# 29        11508  140730453  2017-03-31     75218361       Gustavo
# ..          ...        ...         ...          ...           ...
# 906       23798  170968998  2017-07-16    134945213       Eugenia
# 926       23798  267746501  2018-05-22    169954649     Valentina
# 940       23798  438361087  2019-04-16      1102592          Paul
# 991       24157    4686091  2013-05-20      6128433       Mariela
# 998       24157    6586767  2013-08-18      6886501         Renee
#
#                                               comments lang  len
# 11   El dpto es exacto las fotos. El anfitrión es e...   es  148
# 13                                     Bad experience.   es   15
# 25   El apartamento es muy cómodo, tiene mucha luz ...   es  383
# 28   Como lo exprese en una reseña de mi estadía en...   es  484
# 29   Excelente departamento tanto en ubicacion (2 c...   es  192
# ..                                                 ...  ...  ...
# 906  El depto muy comodo y super completo. limpio y...   es  120
# 926  El departamento es amplio, acogedor y lindo.  ...   es  236
# 940          Todo fenomenal. Muy amable y mucho jabón    es   41
# 991  Es un hermoso loft, muy cálido y bien ubicado....   es  107
# 998  Muy encantadora Virginie, el loft es un muy bu...   es  531
#
# [183 rows x 8 columns]

# %%
# show mean
es_mean = np.mean(df_es['len'])
es_mean
# Out:
# 227.56284153005464

# %%
# show max value
df_es['len'].max()
# Out:
# 841

# %%
# density distibution for en and es
sns.distplot(df_es['len'], hist=False, kde_kws={'clip': (0, 2500)}, label = 'es')
sns.distplot(df_en['len'], hist=False, kde_kws={'clip': (0, 2500)}, label = 'en')
