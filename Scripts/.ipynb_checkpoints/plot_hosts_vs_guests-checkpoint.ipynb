# %%
import pandas as pd
import collections
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
from math import log

# %%
df = pd.read_csv("C:/Users/Cyrus/Documents/GitHub/Researchproject/COMP0031-master/Data/belize/belize_reviews.csv")
dfr = pd.read_csv("C:/Users/Cyrus/Documents/GitHub/Researchproject/COMP0031-master/Data/belize/belize_listings.csv")

# %%
df2 = df[df.comments.str[:34] != "The host canceled this reservation"]
dates = pd.to_datetime(df2['date'])
del df2['date']
df2 = pd.concat((df2,dates), axis = 1, join='inner')
df2
# Out:
#        listing_id         id  reviewer_id reviewer_name  \
# 0           36666     145174       278365            Rb
# 1           36666     167715       258142     Angellini
# 2           36666     172375       268097       Michael
# 3           36666     179895       340713       Melinda
# 4           36666     181056       117024          Gail
# ...           ...        ...          ...           ...
# 39821    39183755  559272354    146550925      Nayerlin
# 39822    39183755  562960822     23535832         Clara
# 39823    39218888  566787572    310056328          Alex
# 39824    39944342  565690422     25461269         Moira
# 39825    39944342  566802048    163469041        Andres
#
#                                                 comments       date
# 0      Monique and Maurice has put Caye Caulker at th... 2010-11-27
# 1      We had the best time, food and conversations w... 2011-08-01
# 2      Great, great place to stay on Caye Caulker. Ve... 2011-01-19
# ...

# %%
#get date of first review and convert dates to date type 
dfr2 = dfr[['id', 'first_review']].copy()
date = pd.to_datetime(dfr2['first_review'])
del dfr2['first_review']
dfr2 = pd.concat((dfr2, date), axis = 1, join='inner')
dfr2
# Out:
#             id first_review
# 0        36666   2010-11-27
# 1        36690   2010-08-13
# 2       108932   2017-12-25
# 3       110483   2013-06-04
# 4       120115   2017-04-18
# ...        ...          ...
# 2816  40394136          NaT
# 2817  40394675          NaT
# 2818  40396843          NaT
# 2819  40397261          NaT
# 2820  40425559          NaT
#
# [2821 rows x 2 columns]

# %%
#remove NaN (hosts with no reviews)
dfr2.dropna(subset = ['first_review'],inplace = True)
dfr2
# Out:
#             id first_review
# 0        36666   2010-11-27
# 1        36690   2010-08-13
# 2       108932   2017-12-25
# 3       110483   2013-06-04
# 4       120115   2017-04-18
# ...        ...          ...
# 2633  39079574   2019-11-16
# 2638  39127463   2019-11-01
# 2647  39183755   2019-10-19
# 2650  39218888   2019-11-20
# 2740  39944342   2019-11-17
#
# [1880 rows x 2 columns]

# %%
df2['year'] = df2['date'].dt.year

df2.sort_values(by='year')
# Out:
#        listing_id         id  reviewer_id reviewer_name  \
# 0           36666     145174       278365            Rb
# 230         36690      78001       173050        Martha
# 231         36690      80916       171788         Emily
# 232         36690     152414       273916       Celeste
# 233         36690     155914       171609         Rondi
# ...           ...        ...          ...           ...
# 25212    17681626  505687682     84578303         India
# 25213    17681626  508909907    231760936        Tamara
# 25214    17681626  511651476    238728429       Ricardo
# 25184    17681626  426326978     13754472       Rachael
# 39825    39944342  566802048    163469041        Andres
#
#                                                 comments       date  year
# 0      Monique and Maurice has put Caye Caulker at th... 2010-11-27  2010
# 230    We really enjoyed staying in Monique and Mauri... 2010-08-13  2010
# ...

# %%
dfr2['year_first_review'] = dfr2['first_review'].dt.year

dfr2.sort_values(by='year_first_review')
# Out:
#             id first_review  year_first_review
# 0        36666   2010-11-27               2010
# 1        36690   2010-08-13               2010
# 15      183285   2011-11-09               2011
# 13      182596   2011-12-28               2011
# 12      179190   2011-10-02               2011
# ...        ...          ...                ...
# 1842  30016986   2019-11-11               2019
# 1838  30016976   2019-06-10               2019
# 1835  30015264   2019-03-24               2019
# 1918  30568927   2019-05-02               2019
# 2740  39944342   2019-11-17               2019
#
# [1880 rows x 3 columns]

# %%
gb1 = df2.groupby('year')
gb1 = gb1.apply(lambda x: len(set(x['reviewer_id'])))
cum1 = gb1.cumsum()
year = cum1.index
year_series = pd.Series(year)
guests = cum1.values
guests_series = pd.Series(guests)

ln_guests = np.log(cum1.values)
ln_guests_series = pd.Series(ln_guests)

ln_frame = {'Year':year_series, 'Guests':ln_guests_series}
frame = {'Year':year_series, 'Guests':guests_series}

ln_result = pd.DataFrame(ln_frame)
result = pd.DataFrame(frame)

# %%
x1 = cum1.index
y1 = cum1.values
#sns.barplot(x1, y1, color ='g')

# %%
gb = dfr2.groupby('year_first_review')
gb = gb.apply(lambda x: len(set(x['id'])))
cum = gb.cumsum()
#x = cum.index
#y = cum.values
ln_hosts = np.log(cum.values)
ln_hosts_series = pd.Series(ln_hosts)

hosts = cum.values
hosts_series = pd.Series(hosts)

result['Hosts'] = hosts_series
ln_result['Hosts'] = ln_hosts_series

#sns.barplot(x, y)

# %%
melted = pd.melt(result, id_vars=['Year'], value_vars=['Guests', 'Hosts'])
melted
# Out:
#     Year variable  value
# 0   2010   Guests      5
# 1   2011   Guests     38
# 2   2012   Guests    152
# 3   2013   Guests    339
# 4   2014   Guests    869
# 5   2015   Guests   2401
# 6   2016   Guests   5788
# 7   2017   Guests  11437
# 8   2018   Guests  21060
# 9   2019   Guests  32441
# 10  2010    Hosts      2
# 11  2011    Hosts      9
# 12  2012    Hosts     17
# 13  2013    Hosts     40
# 14  2014    Hosts    115
# 15  2015    Hosts    239
# 16  2016    Hosts    443
# 17  2017    Hosts    783
# 18  2018    Hosts   1365
# 19  2019    Hosts   1880

# %%
ln_melted = pd.melt(ln_result, id_vars=['Year'], value_vars=['Guests', 'Hosts'])
ln_melted
# Out:
#     Year variable      value
# 0   2010   Guests   1.609438
# 1   2011   Guests   3.637586
# 2   2012   Guests   5.023881
# 3   2013   Guests   5.826000
# 4   2014   Guests   6.767343
# 5   2015   Guests   7.783641
# 6   2016   Guests   8.663542
# 7   2017   Guests   9.344609
# 8   2018   Guests   9.955131
# 9   2019   Guests  10.387178
# 10  2010    Hosts   0.693147
# 11  2011    Hosts   2.197225
# 12  2012    Hosts   2.833213
# 13  2013    Hosts   3.688879
# 14  2014    Hosts   4.744932
# 15  2015    Hosts   5.476464
# 16  2016    Hosts   6.093570
# 17  2017    Hosts   6.663133
# 18  2018    Hosts   7.218910
# 19  2019    Hosts   7.539027

# %%
g = sns.barplot(x = melted.Year, y =melted.value, hue = "variable", data = melted)

# %%
ln_g = sns.barplot(x = ln_melted.Year, y = ln_melted.value, hue = "variable", data = ln_melted)
