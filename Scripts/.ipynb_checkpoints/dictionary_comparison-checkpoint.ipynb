# %%
import pandas as pd
from langdetect import detect
import numpy as np
import nltk
from nltk.stem import WordNetLemmatizer
import string
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_csv('../data/processedDict.csv')

# %%
lemmatised_words = []
df['word'] = df['word'].apply(lambda x: lem.lemmatize(x, pos='n'))
pattern = '|'.join(df['word']) #augment dictionary to pattern form -> used for vectorised function application

# %%
filepath = '../data/en_reviews/taipei_en.csv'
reviews = pd.read_csv(filepath)
del reviews['Unnamed: 0']
comments_original = reviews['comments'] #to add back before saving to csv
reviews
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0            68396    4743816  2013-05-23      3334370         Scott
# 1            68396  279164758  2018-06-20    183745170        Yamada
# 2            68398    2894700  2012-11-16      3534183         Laura
# 3            68398   13416072  2014-05-27     12750484        Maggie
# 4            68398   48514756  2015-09-27     31102107        Romney
# ...            ...        ...         ...          ...           ...
# 141404    40118828  569575737  2019-11-27    124657159       Lokting
# 141405    40132565  570638590  2019-11-30    311853929          Mary
# 141406    40193977  569575328  2019-11-27    304454924       Nerissa
# 141407    40301066  569890456  2019-11-28     28915344           Joy
# 141408    40362558  570672340  2019-11-30     27711194    Yung Chieh
#
#                                                  comments langs
# 0       Great location ( very close to the metro stati...    en
# 1                                    Very good place!!!\n    en
# 2       I enjoyed my stay very much! Spend approx 6 we...    en
# 3       I ended up staying in Studio B. Apartment is c...    en
# 4       I arrived a little early but Vincent valiantly...    en
# ...                                                   ...   ...
# 141404                                    Well apartment.    en
# 141405  The host was very kind and friendly, he replie...    en
# 141406  The room is perfectly clean and embellished wi...    en
# 141407  Great location. It is only minutes from the cl...    en
# 141408  Informative and efficient owner. It’s a walk u...    en
#
# [141409 rows x 7 columns]

# %%
nltk.download('wordnet') #download corpus for lemmatizer to compare results with
# Out:
# [nltk_data] Downloading package wordnet to /Users/hiru/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lem = WordNetLemmatizer() #create lemmatizer

# %%
table = str.maketrans('', '', string.punctuation) #mapping to strip punctuation in review

#strip punct of each review -> lemmatise -> output is list of words so join into sentences
lem_comments = reviews.comments.apply(lambda review: ' '.join(map(str, [lem.lemmatize(word.translate(table), pos='n') for word in review.lower().split()])))

count = lem_comments.str.count(pattern) # # of dictionary words found in each review
length = lem_comments.str.len() # review length

reviews['dict_proportion'] = count/length # save proportions

# %%
"Mean dictionary presence: {:.4%}".format(np.mean(reviews['dict_proportion']))
# Out:
# 'Mean dictionary presence: 5.5840%'

# %%
reviews
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0            68396    4743816  2013-05-23      3334370         Scott
# 1            68396  279164758  2018-06-20    183745170        Yamada
# 2            68398    2894700  2012-11-16      3534183         Laura
# 3            68398   13416072  2014-05-27     12750484        Maggie
# 4            68398   48514756  2015-09-27     31102107        Romney
# ...            ...        ...         ...          ...           ...
# 141404    40118828  569575737  2019-11-27    124657159       Lokting
# 141405    40132565  570638590  2019-11-30    311853929          Mary
# 141406    40193977  569575328  2019-11-27    304454924       Nerissa
# 141407    40301066  569890456  2019-11-28     28915344           Joy
# 141408    40362558  570672340  2019-11-30     27711194    Yung Chieh
#
#                                                  comments langs  \
# 0       Great location ( very close to the metro stati...    en
# 1                                    Very good place!!!\n    en
# 2       I enjoyed my stay very much! Spend approx 6 we...    en
# 3       I ended up staying in Studio B. Apartment is c...    en
# 4       I arrived a little early but Vincent valiantly...    en
# ...                                                   ...   ...
# 141404                                    Well apartment.    en
# 141405  The host was very kind and friendly, he replie...    en
# 141406  The room is perfectly clean and embellished wi...    en
# 141407  Great location. It is only minutes from the cl...    en
# 141408  Informative and efficient owner. It’s a walk u...    en
#
#         dict_proportion
# 0              0.067416
# 1              0.066667
# 2              0.068182
# 3              0.066832
# 4              0.049952
# ...                 ...
# 141404         0.071429
# 141405         0.097143
# 141406         0.084821
# 141407         0.066748
# 141408         0.047264
#
# [141409 rows x 8 columns]

# %%
#overwrite csv in en_reviews
reviews.to_csv(filepath, index = False)
