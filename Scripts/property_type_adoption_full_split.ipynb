# %%
import math
import pandas as pd
from langdetect import detect
import numpy as np
import nltk
from nltk.stem import WordNetLemmatizer
import string
from sklearn.feature_extraction.text import CountVectorizer
import math
import matplotlib.pyplot as plt

# %%
lem = WordNetLemmatizer() #create lemmatizer

# %%
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/shirinharandi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# INPUT HERE
df = pd.read_csv('/Users/shirinharandi/Desktop/COMP0031/Data/en_reviews/tokyo_en.csv')
listings = pd.read_csv('/Users/shirinharandi/Desktop/COMP0031/Data/listings/tokyo_listings.csv')
city_name = "Tokyo"
listings
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              id                            listing_url       scrape_id  \
# 0         35303     https://www.airbnb.com/rooms/35303  20191128233834
# 1        197677    https://www.airbnb.com/rooms/197677  20191128233834
# 2        289597    https://www.airbnb.com/rooms/289597  20191128233834
# 3        370759    https://www.airbnb.com/rooms/370759  20191128233834
# 4        700253    https://www.airbnb.com/rooms/700253  20191128233834
# ...         ...                                    ...             ...
# 13757  40413103  https://www.airbnb.com/rooms/40413103  20191128233834
# 13758  40413645  https://www.airbnb.com/rooms/40413645  20191128233834
# 13759  40415207  https://www.airbnb.com/rooms/40415207  20191128233834
# 13760  40417564  https://www.airbnb.com/rooms/40417564  20191128233834
# 13761  40422866  https://www.airbnb.com/rooms/40422866  20191128233834
#
#       last_scraped                                               name  \
# 0       2019-11-29  La Casa Gaienmae C Harajuku, Omotesando is nearby
# 1       2019-11-29                          Oshiage Holiday Apartment
# 2       2019-11-29                  Private apt in central Tokyo #203
# 3       2019-11-29  Cozy flat #203, local area YET 10 mins to shib...
# 4       2019-11-29                  Private apt in central Tokyo #201
# ...            ...                                                ...
# 13757   2019-11-29   【MONTHLY!】HOUSE IN ASAKUSA. SKY TREE! MAX 16 PP!
# 13758   2019-11-29   3BR House, Easy access to Shinjuku/Shibuya Area!
# 13759   2019-11-29            ★SHEN HOUSE★COZY★E★supermarkets nearby★
# 13760   2019-11-29                                池袋新宿渋谷､上野東京横浜直通赤羽民泊
# 13761   2019-11-29  302西新宿五丁目車站步行4分鐘､近新宿鬧區､餐廳､超市､便利店､藥妝店､速食店､東京都廳及...
#
#                                                  summary  \
# 0      This shared flat is locating at very close to ...
# 1                                                    NaN
# 2                                                    NaN
# 3      So close to busy centers, yet so peaceful! Jus...
# 4                                                    NaN
# ...                                                  ...
# 13757  Recently built! Spacious! Great location! 2 st...
# 13758  Enjoy full access to your own 3 bedroom house ...
# 13759  ★ The home stay is located in the living area ...
# 13760                                 赤羽岩淵駅徒歩30秒､赤羽駅徒歩5分
# 13761                                                NaN
#
#                                                    space  \
# 0      This apartment is 3 bedroom flat shared with t...
# 1      We are happy to welcome you to our apartment, ...
# 2      ::::::::::::::::::::::::::::::::::::::::::::::...
# 3      Cozy and Relaxing, at home feeling in a reside...
# 4      ::::::::::::::::::::::::::::::::::::::::::::::...
# ...                                                  ...
# 13757  【House Facility】 - Futon x 16 - Japanese foot ...
# 13758  The house is larger than most Japanese size pl...
# 13759  ★ 25 square meters, dedicated for urban living...
# 13760                                      清潔､ｱｯﾄﾎｰﾑな雰囲気
# 13761                                                NaN
#
#                                              description experiences_offered  \
# 0      This shared flat is locating at very close to ...                none
# 1      We are happy to welcome you to our apartment, ...                none
# 2      ::::::::::::::::::::::::::::::::::::::::::::::...                none
# 3      So close to busy centers, yet so peaceful! Jus...                none
# 4      ::::::::::::::::::::::::::::::::::::::::::::::...                none
# ...                                                  ...                 ...
# 13757  Recently built! Spacious! Great location! 2 st...                none
# 13758  Enjoy full access to your own 3 bedroom house ...                none
# 13759  ★ The home stay is located in the living area ...                none
# 13760  赤羽岩淵駅徒歩30秒､赤羽駅徒歩5分 清潔､ｱｯﾄﾎｰﾑな雰囲気 365/24 TElMAI...                none
# 13761                                                NaN                none
#
#                                    neighborhood_overview  ...  \
# 0      10 min walking to Harajuku ~ Urahara ~ Omotesa...  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3      Peaceful and residential area just 10 mins awa...  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 13757  The nearest station is Asakusa station. It is ...  ...
# 13758  Tabata station is an inspiring haven of creati...  ...
# 13759  ★ Please do not make any noise in the room aft...  ...
# 13760                                         商店街至近､交通便利  ...
# 13761                                                NaN  ...
#
#       instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                    f                        f  strict_14_with_grace_period
# 1                    f                        f                     moderate
# 2                    t                        f  strict_14_with_grace_period
# 3                    t                        f  strict_14_with_grace_period
# 4                    f                        f  strict_14_with_grace_period
# ...                ...                      ...                          ...
# 13757                f                        f  strict_14_with_grace_period
# 13758                t                        f                     flexible
# 13759                t                        f  strict_14_with_grace_period
# 13760                t                        f                     moderate
# 13761                t                        f                     moderate
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 1                                 f                                f
# 2                                 f                                f
# 3                                 f                                f
# 4                                 f                                f
# ...                             ...                              ...
# 13757                             f                                f
# 13758                             f                                f
# 13759                             f                                f
# 13760                             f                                f
# 13761                             f                                f
#
#        calculated_host_listings_count  \
# 0                                   3
# 1                                   1
# 2                                   2
# 3                                   3
# 4                                   2
# ...                               ...
# 13757                              28
# 13758                              16
# 13759                              24
# 13760                               1
# 13761                               9
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                2
# 1                                                1
# 2                                                2
# 3                                                3
# 4                                                2
# ...                                            ...
# 13757                                           28
# 13758                                           16
# 13759                                           24
# 13760                                            1
# 13761                                            8
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                1
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 13757                                            0
# 13758                                            0
# 13759                                            0
# 13760                                            0
# 13761                                            1
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                                0               0.19
# 1                                                0               1.60
# 2                                                0               1.22
# 3                                                0               1.47
# 4                                                0               1.19
# ...                                            ...                ...
# 13757                                            0                NaN
# 13758                                            0                NaN
# 13759                                            0                NaN
# 13760                                            0                NaN
# 13761                                            0                NaN
#
# [13762 rows x 106 columns]

# %%
df
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0            35303     810980  2011-12-28      1502908         Firuz
# 1            35303    2467161  2012-10-01       350719        Jordan
# 2            35303    3572628  2013-02-18      4917704       Aymeric
# 3            35303    3952097  2013-03-30      3243253      Blandine
# 4            35303    4377509  2013-05-01      1536097      Kayleigh
# ...            ...        ...         ...          ...           ...
# 235399    40148789  567628035  2019-11-23     25926619        Mizuki
# 235400    40155090  567638389  2019-11-23     64148135        Sophie
# 235401    40162550  568061780  2019-11-24    127609714        Bonnie
# 235402    40162550  569588204  2019-11-27     74054421         David
# 235403    40221096  568051681  2019-11-24    303192194        Yedija
#
#                                                  comments langs  \
# 0       Miyuki's has been a great host. Helpful and ve...    en
# 1       Nice apartment in one of the best areas of Tok...    en
# 2       A very nice host and place. The location is in...    en
# 3       Miyuki is the most smily face I met when I lan...    en
# 4       The location's wonderful. It's close to Haraju...    en
# ...                                                   ...   ...
# 235399  It is a nice cozy room. Very near to the stati...    en
# 235400  Great room in a very central location. Very cl...    en
# 235401  A great location and stylish place. Host is gr...    en
# 235402  Amazing places, its just like my apparent  bac...    en
# 235403  What a wonderful host! Super kind, responsive,...    en
#
#         dict_proportion
# 0              0.053279
# 1              0.052817
# 2              0.055556
# 3              0.042071
# 4              0.064426
# ...                 ...
# 235399         0.071429
# 235400         0.058140
# 235401         0.068182
# 235402         0.039106
# 235403         0.054878
#
# [235404 rows x 8 columns]

# %%
listings = listings[['id', 'room_type', 'calculated_host_listings_count']].copy()
listings
# Out:
#              id        room_type  calculated_host_listings_count
# 0         35303     Private room                               3
# 1        197677  Entire home/apt                               1
# 2        289597  Entire home/apt                               2
# 3        370759  Entire home/apt                               3
# 4        700253  Entire home/apt                               2
# ...         ...              ...                             ...
# 13757  40413103  Entire home/apt                              28
# 13758  40413645  Entire home/apt                              16
# 13759  40415207  Entire home/apt                              24
# 13760  40417564  Entire home/apt                               1
# 13761  40422866  Entire home/apt                               9
#
# [13762 rows x 3 columns]

# %%
listings['is_superhost'] = np.where(listings['calculated_host_listings_count'] >= 10, 'Yes', listings['calculated_host_listings_count'])
listings['is_superhost'] = np.where(listings['calculated_host_listings_count'] < 10, 'No', listings['is_superhost'])
listings = listings.rename(columns={"id": "listing_id"})
listings
# Out:
#        listing_id        room_type  calculated_host_listings_count  \
# 0           35303     Private room                               3
# 1          197677  Entire home/apt                               1
# 2          289597  Entire home/apt                               2
# 3          370759  Entire home/apt                               3
# 4          700253  Entire home/apt                               2
# ...           ...              ...                             ...
# 13757    40413103  Entire home/apt                              28
# 13758    40413645  Entire home/apt                              16
# 13759    40415207  Entire home/apt                              24
# 13760    40417564  Entire home/apt                               1
# 13761    40422866  Entire home/apt                               9
#
#       is_superhost
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ...            ...
# 13757          Yes
# 13758          Yes
# 13759          Yes
# 13760           No
# 13761           No
#
# [13762 rows x 4 columns]

# %%
out = pd.merge(df, listings, on='listing_id')
out
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0            35303     810980  2011-12-28      1502908         Firuz
# 1            35303    2467161  2012-10-01       350719        Jordan
# 2            35303    3572628  2013-02-18      4917704       Aymeric
# 3            35303    3952097  2013-03-30      3243253      Blandine
# 4            35303    4377509  2013-05-01      1536097      Kayleigh
# ...            ...        ...         ...          ...           ...
# 235399    40148789  567628035  2019-11-23     25926619        Mizuki
# 235400    40155090  567638389  2019-11-23     64148135        Sophie
# 235401    40162550  568061780  2019-11-24    127609714        Bonnie
# 235402    40162550  569588204  2019-11-27     74054421         David
# 235403    40221096  568051681  2019-11-24    303192194        Yedija
#
#                                                  comments langs  \
# 0       Miyuki's has been a great host. Helpful and ve...    en
# 1       Nice apartment in one of the best areas of Tok...    en
# 2       A very nice host and place. The location is in...    en
# 3       Miyuki is the most smily face I met when I lan...    en
# 4       The location's wonderful. It's close to Haraju...    en
# ...                                                   ...   ...
# 235399  It is a nice cozy room. Very near to the stati...    en
# 235400  Great room in a very central location. Very cl...    en
# 235401  A great location and stylish place. Host is gr...    en
# 235402  Amazing places, its just like my apparent  bac...    en
# 235403  What a wonderful host! Super kind, responsive,...    en
#
#         dict_proportion        room_type  calculated_host_listings_count  \
# 0              0.053279     Private room                               3
# 1              0.052817     Private room                               3
# 2              0.055556     Private room                               3
# 3              0.042071     Private room                               3
# 4              0.064426     Private room                               3
# ...                 ...              ...                             ...
# 235399         0.071429  Entire home/apt                               2
# 235400         0.058140  Entire home/apt                              12
# 235401         0.068182  Entire home/apt                               1
# 235402         0.039106  Entire home/apt                               1
# 235403         0.054878  Entire home/apt                               4
#
#        is_superhost
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 235399           No
# 235400          Yes
# 235401           No
# 235402           No
# 235403           No
#
# [235404 rows x 11 columns]

# %%
# out.to_csv(r'property_type_and_superhosts/tokyo_type.csv')

# %%
dictionary = pd.read_csv('../data/processedDict.csv')
dictionary['word'] = dictionary['word'].apply(lambda x: lem.lemmatize(x, pos='n'))

# %%
# filepath = '../data/en_reviews/Manchester.csv'
# reviews = pd.read_csv(filepath)

# reviews = reviews['date']
# reviews

reviews = out 
table = str.maketrans('', '', string.punctuation) #mapping to strip punctuation in review

#strip punct of each review -> lemmatise -> output is list of words so join into sentences
reviews['comments'] = reviews.comments.apply(lambda review: ' '.join(map(str, [lem.lemmatize(word.translate(table), pos='n') for word in review.lower().split()])))
reviews

reviews['date'] = pd.to_datetime(reviews['date'])

# %%
#### DELETE THIS LATER ###
mask = (reviews['date'] >= '2014-01-01') & (reviews['date'] < '2017-01-01')
reviews = reviews.loc[mask].copy()
reviews
# Out:
#        listing_id         id       date  reviewer_id reviewer_name  \
# 7           35303   19211289 2014-09-08      2893501           Yan
# 8           35303   23170075 2014-11-24      8674085           San
# 9           35303   27408652 2015-03-03     27944062      Kim Seng
# 10          35303   27846973 2015-03-13     28171041          Matt
# 11          35303   30457445 2015-04-22     17232501         James
# ...           ...        ...        ...          ...           ...
# 91745    16460921  123558788 2016-12-29     47496794             焱
# 92183    16471345  124015197 2016-12-31     27950605        JooHee
# 92300    16471780  122962520 2016-12-26       546631        Audrey
# 92403    16480522  122514971 2016-12-23     51882443           Ben
# 92538    16523671  124031291 2016-12-31    107321056       Nicolas
#
#                                                 comments langs  \
# 7      thanks miyuki for a great stay a described cle...    en
# 8      it wa great stay everything wa a described and...    en
# 9      my first ever solo trip to tokyo japan ha been...    en
# 10     this wa a lovely place to stay for my first ti...    en
# 11     miyuki wa a very accommodating host that offer...    en
# ...                                                  ...   ...
# 91745  great place to stay home is a bit cold even if...    en
# 92183  this is in a very convenient spot right by shi...    en
# 92300  my family and i came from osaka and checked in...    en
# 92403  very nice house and host wa very nice really g...    en
# 92538                       very nice and cute mini home    en
#
#        dict_proportion        room_type  calculated_host_listings_count  \
# 7             0.043478     Private room                               3
# 8             0.035176     Private room                               3
# 9             0.058496     Private room                               3
# 10            0.047923     Private room                               3
# 11            0.046225     Private room                               3
# ...                ...              ...                             ...
# 91745         0.050000  Entire home/apt                              11
# 92183         0.066667  Entire home/apt                              14
# 92300         0.041170  Entire home/apt                              14
# 92403         0.047244     Private room                               3
# 92538         0.107143  Entire home/apt                              11
#
#       is_superhost
# 7               No
# 8               No
# 9               No
# 10              No
# 11              No
# ...            ...
# 91745          Yes
# 92183          Yes
# 92300          Yes
# 92403           No
# 92538          Yes
#
# [24233 rows x 11 columns]

# %%
reviews
# Out:
#        listing_id         id       date  reviewer_id reviewer_name  \
# 7           35303   19211289 2014-09-08      2893501           Yan
# 8           35303   23170075 2014-11-24      8674085           San
# 9           35303   27408652 2015-03-03     27944062      Kim Seng
# 10          35303   27846973 2015-03-13     28171041          Matt
# 11          35303   30457445 2015-04-22     17232501         James
# ...           ...        ...        ...          ...           ...
# 91745    16460921  123558788 2016-12-29     47496794             焱
# 92183    16471345  124015197 2016-12-31     27950605        JooHee
# 92300    16471780  122962520 2016-12-26       546631        Audrey
# 92403    16480522  122514971 2016-12-23     51882443           Ben
# 92538    16523671  124031291 2016-12-31    107321056       Nicolas
#
#                                                 comments langs  \
# 7      thanks miyuki for a great stay a described cle...    en
# 8      it wa great stay everything wa a described and...    en
# 9      my first ever solo trip to tokyo japan ha been...    en
# 10     this wa a lovely place to stay for my first ti...    en
# 11     miyuki wa a very accommodating host that offer...    en
# ...                                                  ...   ...
# 91745  great place to stay home is a bit cold even if...    en
# 92183  this is in a very convenient spot right by shi...    en
# 92300  my family and i came from osaka and checked in...    en
# 92403  very nice house and host wa very nice really g...    en
# 92538                       very nice and cute mini home    en
#
#        dict_proportion        room_type  calculated_host_listings_count  \
# 7             0.043478     Private room                               3
# 8             0.035176     Private room                               3
# 9             0.058496     Private room                               3
# 10            0.047923     Private room                               3
# 11            0.046225     Private room                               3
# ...                ...              ...                             ...
# 91745         0.050000  Entire home/apt                              11
# 92183         0.066667  Entire home/apt                              14
# 92300         0.041170  Entire home/apt                              14
# 92403         0.047244     Private room                               3
# 92538         0.107143  Entire home/apt                              11
#
#       is_superhost
# 7               No
# 8               No
# 9               No
# 10              No
# 11              No
# ...            ...
# 91745          Yes
# 92183          Yes
# 92300          Yes
# 92403           No
# 92538          Yes
#
# [24233 rows x 11 columns]

# %%
def get_trends_nice(category, subcats, reviews):
    years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
    allwords = reviews['comments'].tolist()
    allwords = " ".join(allwords)
    unique_words = set(allwords.split(' '))
    len(unique_words)

    unique_words = list(unique_words)
    unique_words = [string for string in unique_words if string != ""]
#     len(unique_words)

    ls = []
    for word in unique_words:
        word = ''.join([i for i in word if not i.isdigit()])
        ls += [word]
    unique_words= ls
    unique_words = [string for string in unique_words if string != ""]
    unique_words = list(dict.fromkeys(unique_words))

    def countWords(word, review):
        count = 0
        for i in review:
            if i == word:
                count+=1
        return count

    def getDenom(review, unique_words):
        count = 0
        den = 0
        ls = []
        review = review.split()
        for word in review:
            kmp = countWords(word, review)
            if (kmp > 0 and word not in ls):
                ls += [word]
                den += math.log(1 + kmp)
        return den

    reviews['den'] = reviews['comments'].apply(lambda x: getDenom(x, unique_words))

    def getNom(category, review, dictionary, cat_levl="cat_lev1"):
        nom = 0
        review = review.split()
        dictionaryWords = dictionary[(dictionary[cat_levl] == category)]
        dictionaryWords = dictionaryWords['word']
        for word in dictionaryWords:
            nom += math.log(1 + review.count(word))
        return nom

    reviews['temp'] = reviews['comments'].apply(lambda x: getNom(category, x, dictionary))
    reviews[category] = reviews['temp']*100/reviews['den']

    k = {}
    for subcat in subcats:
        temp = reviews['comments'].apply(lambda x: getNom(subcat, x, dictionary, cat_levl="cat_lev3"))
        reviews[subcat] = temp * 100 / reviews["den"]
        k[subcat] = reviews[subcat].loc[reviews[subcat] > 0].min()
        
    print(k)
    
    k_business= reviews[category].loc[reviews[category] > 0]
    k_business = k_business.min()
    print(k_business)

    def adoptionForSetOfReviews(category, setOfReviews, dictionary, startDate, endDate, k):
        adoption = 1
        mask = (setOfReviews['date'] >= startDate) & (setOfReviews['date'] < endDate)
        setOfReviews = setOfReviews.loc[mask]
        setOfReviews = setOfReviews[category]
        if (len(setOfReviews) == 0):
            return 0
        else:
            b = 1/len(setOfReviews)
            for review in setOfReviews:
                adoption *= math.pow((review + k),b)
            adoption = adoption - k
            return adoption

    d2 = {'year' : years, 'value':0.0}
    out = pd.DataFrame(data=d2)
    
    for i in range(len(years)):
        out.at[i, "value_{}".format(category)] = adoptionForSetOfReviews(category, reviews, dictionary, "{}-01-01".format(years[i]), "{}-01-01".format(years[i] + 1), k_business)
        for subcat in subcats:
            out.at[i, "value_{}_{}".format(category, subcat)] = adoptionForSetOfReviews(subcat, reviews, dictionary, "{}-01-01".format(years[i]), "{}-01-01".format(years[i] + 1), k[subcat])

    return out

# %%
house_types = ["Private room", "Entire home/apt", "Shared room"]
soci_subcats = ["meal", "people", "personality_host", "talking", "sharing"]
busi_subcats = ['location', 'communication', 'personality_host2', 'property_type', 'logistic', 'advice', 'facilities', 'interiors']

# %%
r = reviews.loc[reviews["room_type"] == house_types[0]].copy()

soci = get_trends_nice("social", soci_subcats, r)
soci['coef'] = soci['value_social'] / (soci['value_social_meal'] + soci['value_social_people']+soci['value_social_personality_host'] + soci['value_social_talking'] + soci['value_social_sharing'])

soci['value_social_meal'] = soci['value_social_meal']*soci['coef']
soci['value_social_people'] = soci['value_social_people']*soci['coef']
soci['value_social_personality_host'] = soci['value_social_personality_host']*soci['coef']
soci['value_social_talking'] = soci['value_social_talking']*soci['coef']
soci['value_social_sharing'] = soci['value_social_sharing']*soci['coef']

a = pd.DataFrame(columns=["year", "subcat", "val"])

for subcat in soci_subcats:
    ap = {"year": soci["year"], "val": soci["value_social_{}".format(subcat)]}
    ap = pd.DataFrame(data=ap)
    ap["subcat"] = subcat
    a = a.append(ap)
    
pivot_social = a.pivot(index='year', columns='subcat', values='val')

ax = pivot_social.loc[:,['meal','people', 'personality_host', 'sharing', 'talking']].plot.bar(stacked=True, figsize=(10,7), color=['#351800','#D85907','#D88A07','#FFA900','#FFD70F'])
plt.title("{} Social {}".format(city_name, house_types[0]))
ax.get_legend().remove()

# plt.bar(temp["year"], temp["value_social"])
# Out:
# {'meal': 0.2923426880231312, 'people': 0.28397382988638475, 'personality_host': 0.3177491220287004, 'talking': 0.2941808490625492, 'sharing': 0.28397382988638475}
# 0.3469604658318127
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
r = reviews.loc[reviews["room_type"] == house_types[1]].copy()

soci = get_trends_nice("social", soci_subcats, r)
soci['coef'] = soci['value_social'] / (soci['value_social_meal'] + soci['value_social_people']+soci['value_social_personality_host'] + soci['value_social_talking'] + soci['value_social_sharing'])

soci['value_social_meal'] = soci['value_social_meal']*soci['coef']
soci['value_social_people'] = soci['value_social_people']*soci['coef']
soci['value_social_personality_host'] = soci['value_social_personality_host']*soci['coef']
soci['value_social_talking'] = soci['value_social_talking']*soci['coef']
soci['value_social_sharing'] = soci['value_social_sharing']*soci['coef']

a = pd.DataFrame(columns=["year", "subcat", "val"])

for subcat in soci_subcats:
    ap = {"year": soci["year"], "val": soci["value_social_{}".format(subcat)]}
    ap = pd.DataFrame(data=ap)
    ap["subcat"] = subcat
    a = a.append(ap)
    
pivot_social = a.pivot(index='year', columns='subcat', values='val')

ax = pivot_social.loc[:,['meal','people', 'personality_host', 'sharing', 'talking']].plot.bar(stacked=True, figsize=(10,7), color=['#351800','#D85907','#D88A07','#FFA900','#FFD70F'])
plt.title("{} Social {}".format(city_name, house_types[1]))
ax.get_legend().remove()

# plt.bar(temp["year"], temp["value_social"])
# Out:
# {'meal': 0.29096954996424856, 'people': 0.3007202551847854, 'personality_host': 0.2837977846174791, 'talking': 0.3117131348496922, 'sharing': 0.2837977846174791}
# 0.34456163927256545

# %%
r = reviews.loc[reviews["room_type"] == house_types[2]].copy()

soci = get_trends_nice("social", soci_subcats, r)
soci['coef'] = soci['value_social'] / (soci['value_social_meal'] + soci['value_social_people']+soci['value_social_personality_host'] + soci['value_social_talking'] + soci['value_social_sharing'])

soci['value_social_meal'] = soci['value_social_meal']*soci['coef']
soci['value_social_people'] = soci['value_social_people']*soci['coef']
soci['value_social_personality_host'] = soci['value_social_personality_host']*soci['coef']
soci['value_social_talking'] = soci['value_social_talking']*soci['coef']
soci['value_social_sharing'] = soci['value_social_sharing']*soci['coef']

a = pd.DataFrame(columns=["year", "subcat", "val"])

for subcat in soci_subcats:
    ap = {"year": soci["year"], "val": soci["value_social_{}".format(subcat)]}
    ap = pd.DataFrame(data=ap)
    ap["subcat"] = subcat
    a = a.append(ap)
    
pivot_social = a.pivot(index='year', columns='subcat', values='val')

ax = pivot_social.loc[:,['meal','people', 'personality_host', 'sharing', 'talking']].plot.bar(stacked=True, figsize=(10,7), color=['#351800','#D85907','#D88A07','#FFA900','#FFD70F'])
plt.title("{} Social {}".format(city_name, house_types[2]))
ax.get_legend().remove()

# plt.bar(temp["year"], temp["value_social"])
# Out:
# {'meal': 0.39265164920206935, 'people': 0.4580552598242656, 'personality_host': 0.3477031743796823, 'talking': 0.4009935728059297, 'sharing': 0.4009935728059297}
# 0.5392772461704942

# %%
r = reviews.loc[reviews["room_type"] == house_types[0]].copy()

busi = get_trends_nice("business", busi_subcats, r)
busi['coef'] = busi['value_business'] / (busi['value_business_location'] + busi['value_business_communication']+busi['value_business_personality_host2'] + busi['value_business_property_type'] + busi['value_business_logistic']+busi['value_business_facilities'] + busi['value_business_advice']+busi['value_business_interiors'])

busi['value_business_communication'] = busi['value_business_communication']*busi['coef']
busi['value_business_location'] = busi['value_business_location']*busi['coef']
busi['value_business_personality_host2'] = busi['value_business_personality_host2']*busi['coef']
busi['value_business_advice'] = busi['value_business_advice']*busi['coef']
busi['value_business_property_type'] = busi['value_business_property_type']*busi['coef']
busi['value_business_facilities'] = busi['value_business_facilities']*busi['coef']
busi['value_business_interiors'] = busi['value_business_interiors']*busi['coef']
busi['value_business_logistic'] = busi['value_business_logistic']*busi['coef']

a = pd.DataFrame(columns=["year", "subcat", "val"])

for subcat in busi_subcats:
    ap = {"year": busi["year"], "val": busi["value_business_{}".format(subcat)]}
    ap = pd.DataFrame(data=ap)
    ap["subcat"] = subcat
    a = a.append(ap)
    
pivot_business = a.pivot(index='year', columns='subcat', values='val')

ax = pivot_business.loc[:, ['location', 'communication', 'personality_host2', 'property_type', 'logistic', 'advice', 'facilities', 'interiors']].plot.bar(stacked=True, figsize=(10,7), color=['#143258','#235BA0','#70A9C1','#B1CEDB','#16B9FF','#BCEBFF','#119DAF', '#DFC3D4'])
plt.title("{} Business {}".format(city_name, house_types[0]))
ax.get_legend().remove()

# plt.bar(temp["year"], temp["value_social"])
# Out:
# {'location': 0.5662254497117319, 'communication': 0.3157105503212449, 'personality_host2': 0.28397382988638475, 'property_type': 0.31082849897059256, 'logistic': 0.3054037348586777, 'advice': 0.2923426880231312, 'facilities': 0.3157105503212449, 'interiors': 0.39440038106491915}
# 1.33633200713629

# %%
r = reviews.loc[reviews["room_type"] == house_types[1]].copy()

busi = get_trends_nice("business", busi_subcats, r)
busi['coef'] = busi['value_business'] / (busi['value_business_location'] + busi['value_business_communication']+busi['value_business_personality_host2'] + busi['value_business_property_type'] + busi['value_business_logistic']+busi['value_business_facilities'] + busi['value_business_advice']+busi['value_business_interiors'])

busi['value_business_communication'] = busi['value_business_communication']*busi['coef']
busi['value_business_location'] = busi['value_business_location']*busi['coef']
busi['value_business_personality_host2'] = busi['value_business_personality_host2']*busi['coef']
busi['value_business_advice'] = busi['value_business_advice']*busi['coef']
busi['value_business_property_type'] = busi['value_business_property_type']*busi['coef']
busi['value_business_facilities'] = busi['value_business_facilities']*busi['coef']
busi['value_business_interiors'] = busi['value_business_interiors']*busi['coef']
busi['value_business_logistic'] = busi['value_business_logistic']*busi['coef']

a = pd.DataFrame(columns=["year", "subcat", "val"])

for subcat in busi_subcats:
    ap = {"year": busi["year"], "val": busi["value_business_{}".format(subcat)]}
    ap = pd.DataFrame(data=ap)
    ap["subcat"] = subcat
    a = a.append(ap)
    
pivot_business = a.pivot(index='year', columns='subcat', values='val')

ax = pivot_business.loc[:, ['location', 'communication', 'personality_host2', 'property_type', 'logistic', 'advice', 'facilities', 'interiors']].plot.bar(stacked=True, figsize=(10,7), color=['#143258','#235BA0','#70A9C1','#B1CEDB','#16B9FF','#BCEBFF','#119DAF', '#DFC3D4'])
plt.title("{} Business {}".format(city_name, house_types[1]))
ax.get_legend().remove()

# plt.bar(temp["year"], temp["value_social"])
# Out:
# {'location': 0.655961200387919, 'communication': 0.29648165737600723, 'personality_host2': 0.2771103716488368, 'property_type': 0.3235450471057572, 'logistic': 0.2941202599414157, 'advice': 0.2771103716488368, 'facilities': 0.2870161155674658, 'interiors': 0.36519585107390795}
# 1.5834402251970534

# %%
r = reviews.loc[reviews["room_type"] == house_types[2]].copy()

busi = get_trends_nice("business", busi_subcats, r)
busi['coef'] = busi['value_business'] / (busi['value_business_location'] + busi['value_business_communication']+busi['value_business_personality_host2'] + busi['value_business_property_type'] + busi['value_business_logistic']+busi['value_business_facilities'] + busi['value_business_advice']+busi['value_business_interiors'])

busi['value_business_communication'] = busi['value_business_communication']*busi['coef']
busi['value_business_location'] = busi['value_business_location']*busi['coef']
busi['value_business_personality_host2'] = busi['value_business_personality_host2']*busi['coef']
busi['value_business_advice'] = busi['value_business_advice']*busi['coef']
busi['value_business_property_type'] = busi['value_business_property_type']*busi['coef']
busi['value_business_facilities'] = busi['value_business_facilities']*busi['coef']
busi['value_business_interiors'] = busi['value_business_interiors']*busi['coef']
busi['value_business_logistic'] = busi['value_business_logistic']*busi['coef']

a = pd.DataFrame(columns=["year", "subcat", "val"])

for subcat in busi_subcats:
    ap = {"year": busi["year"], "val": busi["value_business_{}".format(subcat)]}
    ap = pd.DataFrame(data=ap)
    ap["subcat"] = subcat
    a = a.append(ap)
    
pivot_business = a.pivot(index='year', columns='subcat', values='val')

ax = pivot_business.loc[:, ['location', 'communication', 'personality_host2', 'property_type', 'logistic', 'advice', 'facilities', 'interiors']].plot.bar(stacked=True, figsize=(10,7), color=['#143258','#235BA0','#70A9C1','#B1CEDB','#16B9FF','#BCEBFF','#119DAF', '#DFC3D4'])
plt.title("{} Business {}".format(city_name, house_types[2]))
ax.get_legend().remove()

# plt.bar(temp["year"], temp["value_social"])
# Out:
# {'location': 0.8683734506909576, 'communication': 0.36325405312545733, 'personality_host2': 0.39265164920206935, 'property_type': 0.43102177096202465, 'logistic': 0.3477031743796823, 'advice': 0.3477031743796823, 'facilities': 0.39265164920206935, 'interiors': 0.42541113841585954}
# 1.7856623707486023
